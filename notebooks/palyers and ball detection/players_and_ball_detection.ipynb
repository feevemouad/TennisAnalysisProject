# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("tennistracker-dogbm").project("tennis-tracker-duufq")
version = project.version(17)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.5, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to tennis-tracker-17 in yolov8:: 100%|██████████| 4624/4624 [00:01<00:00, 3385.23it/s]

# %%
import shutil

shutil.move("/content/tennis-tracker-17/test", "/content/tennis-tracker-17/tennis-tracker-17/test")
shutil.move("/content/tennis-tracker-17/train", "/content/tennis-tracker-17/tennis-tracker-17/train")
shutil.move("/content/tennis-tracker-17/valid", "/content/tennis-tracker-17/tennis-tracker-17/valid")
# Out:
# '/content/tennis-tracker-17/tennis-tracker-17/valid'

# %%
! yolo task=detect \
mode=train \
model=yolov8s.pt \
data={dataset.location}/data.yaml \
epochs=100 \
imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 215MB/s]
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
